# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### Introduction

# %% [markdown]
# Based on the data I analyzed and commented on, I came up with 3 analyzes and visualizations as follows:<br>
# 1. Favorite and reetweet of four stage dog: doggo-floofer-pupper-puppo<br>
# 2. The rating rate on a 10 scale: rating_numerator/rating_denominator<br>
# 3. Time frame for users to use tweets in dataset

# %% [markdown]
# ### Background

# %% [markdown]
# 1. Favorite and reetweet of four stage dog: doggo-floofer-pupper-puppo

# %%
from IPython.display import Image
Image(filename='Chart1.png')

# %% [markdown]
# Display chart show total value counts user favorite count and retweet for stage dog<br>
# Data:<br>
# doggo:favorite_count(1.119.195)	retweet_count(375.755)<br>
# floofer: favorite_count(77.989)	retweet_count(27.629)<br>
# pupper: favorite_count(1.259.255)	retweet_count(386.819)<br>
# puppo: favorite_count(428.959)	retweet_count(116.410)<br>
# doggo,floofer: favorite_count(14.758)	retweet_count(2776)
# doggo,pupper: favorite_count(107.553)	retweet_count(30.851)
# doggo,puppo: favorite_count(41.690)	retweet_count(16.037)

# %% [markdown]
# 2. The rating rate on a 10 scale: rating_numerator/rating_denominator

# %%
Image(filename='Chart2.png')

# %% [markdown]
# Display chart show rating rate rating_numerator/rating_denominator on 10 score scale<br>
# Ratio smaller 10/10 is 21%<br>
# Ratio equa 10/10 is 20%<br>
# Ratio bigger 10/10 is 59%

# %% [markdown]
# 3. Time frame for users to use tweets in dataset

# %%
Image(filename='Chart3.png')

# %% [markdown]
# Display chart show frame user using tweet<br>
# Time lines 24h<br>
# Frame time >5h and <22h is 41%<br>
# Frame time <5h or >22h is 59%

# %% [markdown]
# ### Conclution

# %% [markdown]
# **Chart show favorire and retweet count four stage of dog**<br>
# There are 4 stages of dogs in the data<br>
# According to the chart it can be observed that:<br>
# The pupper stage is highly appreciated and retweeted by users<br>
# The floover phase may not be appreciated by many users<br>
# Perhaps this is obvious when the pupper stage when the dog is very young, looks very cute, all ages love puppies at this stage.

# %% [markdown]
# **Chart show the rating rage on a 10 scale**<br>
# In general, users give good reviews about the dogs.<br>
# 59% over 10<br>
# 21% equals 10<br>
# Everyone has positive reviews when looking at pictures of dogs

# %% [markdown]
# **Chart shows frame user using tweet**<br>
# Perhaps the trend of social network users is very late.<br>
# Objectively commenting, the time frame before 5 am is too early and after 10 pm is too late when still using a phone or computer.<br>
# It's really not good for health.<br>
# But it's a good signal about the demand for the app for tweets
